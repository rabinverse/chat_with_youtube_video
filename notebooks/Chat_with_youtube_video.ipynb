# %%
import os

os.environ["GOOGLE_API_KEY"] = "YOUR_GOOGLE_API"

# %%
# !pip install -q youtube-transcript-api langchain-community langchain-google-genai google-generativeai faiss-cpu tiktoken python-dotenv langchain langchain-text-splitters

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_google_genai import GoogleGenerativeAI, GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
# video_id = "fh2dBmLN-ZM" # only the ID, not full URL
# try:
#     # If you don’t care which language, this returns the “best” one
#     transcript_list = YouTubeTranscriptApi.get_transcript(video_id, languages=["en"])

#     # Flatten it to plain text
#     transcript = " ".join(chunk["text"] for chunk in transcript_list)
#     print(transcript)

# except TranscriptsDisabled:
#     print("No captions available for this video.")

# %%
video_id = "K4Ze-Sp6aUE"

try:
    # 1. Create an instance of the API

    api = YouTubeTranscriptApi()

    # 2. Use .fetch() instead of .get_transcript()
    # 3. Call .to_raw_data() to get the familiar list of dictionaries
    transcript_list = api.fetch(video_id, languages=["en"]).to_raw_data()

    # Join the text parts into one string
    transcript = " ".join(chunk["text"] for chunk in transcript_list)
    print("Transcript fetched successfully!")
    print(transcript[:500])

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Transcript fetched successfully!
# ANDREW HUBERMAN: Welcome to
# the Huberman Lab podcast, where we discuss science
# and science-based tools for everyday life. I'm Andrew Huberman,
# and I'm a professor of neurobiology
# and ophthalmology at Stanford School of Medicine. Today, my guest is
# Dr. Layne Norton. Dr. Norton is one of
# the foremost experts in protein metabolism,
# fat loss, and nutrition. He did his degrees in
# biochemistry and nutritional sciences and is considered
# one of the world experts in understanding how we
# extract energy fr

# %%
transcript_list[:20]
# Out:
# [{'text': 'ANDREW HUBERMAN: Welcome to\nthe Huberman Lab podcast,',
#   'start': 0.0,
#   'duration': 2.22},
#  {'text': 'where we discuss science\nand science-based tools',
#   'start': 2.22,
#   'duration': 2.67},
#  {'text': 'for everyday life.', 'start': 4.89, 'duration': 0.78},
#  {'text': "I'm Andrew Huberman,\nand I'm a professor",
#   'start': 9.13,
#   'duration': 1.77},
#  {'text': 'of neurobiology\nand ophthalmology',
#   'start': 10.9,
#   'duration': 2.16},
#  {'text': 'at Stanford School of Medicine.', 'start': 13.06, 'duration': 1.68},
#  {'text': 'Today, my guest is\nDr. Layne Norton.',
#   'start': 14.74,
#   'duration': 2.28},
#  {'text': 'Dr. Norton is one of\nthe foremost experts',
#   'start': 17.02,
#   'duration': 2.1},
#  {'text': 'in protein metabolism,\nfat loss, and nutrition.',
#   'start': 19.12,
#   'duration': 3.09},
#  {'text': 'He did his degrees in\nbiochemistry and nutritional',
#   'start': 22.21,
#   'duration': 2.64},
#  {'text': 'sciences and is considered\none of the world experts',
#   'start': 24.85,
#   'duration': 2.97},
#  {'text': 'in understanding how we\nextract energy from our food',
#   'start': 27.82,
#   'duration': 3.15},
#  {'text': 'and how exercise and what we\neat combine to impact things',
#   'start': 30.97,
#   'duration': 4.41},
#  {'text': 'like body composition\nand overall health.',
#   'start': 35.38,
#   'duration': 2.83},
#  {'text': 'Today, we discuss an\nenormous number of topics',
#   'start': 38.21,
#   'duration': 2.21},
#  {'text': 'under the umbrella of\nnutrition and fitness,',
#   'start': 40.42,
#   'duration': 2.31},
#  {'text': 'including, for instance,\nwhat is energy balance?',
#   'start': 42.73,
#   'duration': 3.12},
#  {'text': 'That is, how do we actually\nextract energy from our food?',
#   'start': 45.85,
#   'duration': 3.58},
#  {'text': 'We also discuss the\nsomewhat controversial topic',
#   'start': 49.43,
#   'duration': 2.39},
#  {'text': 'of artificial sweeteners,\nwhether or not',
#   'start': 51.82,
#   'duration': 1.8}]

# %%
transcript_list[-20:]
# Out:
# [{'text': "And if you're not already\nfollowing us on social media,",
#   'start': 13728.41,
#   'duration': 2.5},
#  {'text': 'we are Huberman\nLab on Instagram,',
#   'start': 13730.91,
#   'duration': 2.06},
#  {'text': 'Huberman Lab on Twitter, and\nHuberman Lab on Facebook.',
#   'start': 13732.97,
#   'duration': 2.76},
#  {'text': 'And at all of those\nsites, I provide',
#   'start': 13735.73,
#   'duration': 2.28},
#  {'text': 'science and science-related\ntools for mental health,',
#   'start': 13738.01,
#   'duration': 2.422},
#  {'text': 'physical health, and\nperformance, some of which',
#   'start': 13740.432,
#   'duration': 1.958},
#  {'text': 'overlap with information covered\non the Huberman Lab podcast,',
#   'start': 13742.39,
#   'duration': 2.88},
#  {'text': 'but often which is distinct\nfrom information covered',
#   'start': 13745.27,
#   'duration': 2.76},
#  {'text': 'on the Huberman Lab podcast.', 'start': 13748.03, 'duration': 1.23},
#  {'text': "So again, that's Huberman\nLab on Instagram, Twitter,",
#   'start': 13749.26,
#   'duration': 2.35},
#  {'text': 'and Facebook.', 'start': 13751.61, 'duration': 0.633},
#  {'text': "Thank you once again for joining\nme for today's discussion",
#   'start': 13752.243,
#   'duration': 2.417},
#  {'text': 'with Dr. Layne Norton.', 'start': 13754.66, 'duration': 1.26},
#  {'text': 'If you are interested\nin some of the resources',
#   'start': 13755.92,
#   'duration': 2.04},
#  {'text': 'that he and I discussed,\nincluding his Carbon app as',
#   'start': 13757.96,
#   'duration': 3.06},
#  {'text': 'well as other resources\nthat he provides,',
#   'start': 13761.02,
#   'duration': 2.01},
#  {'text': 'please go to the links in\nthe show note captions.',
#   'start': 13763.03,
#   'duration': 2.82},
#  {'text': 'And last but\ncertainly not least,',
#   'start': 13765.85,
#   'duration': 2.17},
#  {'text': 'thank you for your\ninterest in science.',
#   'start': 13768.02,
#   'duration': 1.67},
#  {'text': '[MUSIC PLAYING]', 'start': 13769.69, 'duration': 3.05}]

# %% [markdown]
# ---
#
# # Chunking

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunk = splitter.create_documents([transcript])

# %%
len(chunk)
# Out:
# 290

# %% [markdown]
# ---

# %% [markdown]
# # Embedding generation & storing in vector store

# %%
embeddings = GoogleGenerativeAIEmbeddings(model="models/text-embedding-004")
vector_store = FAISS.from_documents(chunk, embeddings)

# %%
list(vector_store.index_to_docstore_id.items())[-10:]
# Out:
# [(280, '9c2176e1-be9d-44b0-836d-f3ed21bc9a4a'),
#  (281, '1783d87e-3952-4603-990b-b7729c3357be'),
#  (282, '857b3a17-9407-430b-bb16-66933558731d'),
#  (283, '1e2a747e-ac7b-4cfe-b784-a82461534ed4'),
#  (284, '55400379-0834-48a7-879e-3af9c8378d4e'),
#  (285, '32694026-b1cc-4387-8ed5-8bd4acb90f9b'),
#  (286, '9b1d25ce-27e1-413d-ab97-3a790f424030'),
#  (287, '30334820-ebf0-4984-ab9f-1809a9262c2e'),
#  (288, '726feaf1-0ba3-41ff-bc36-901ffa98e388'),
#  (289, '88b631ec-128f-4d22-bfb9-d3bdcccded84')]

# %%
vector_store.get_by_ids(["88b631ec-128f-4d22-bfb9-d3bdcccded84"])
# Out:
# []

# %% [markdown]
# ---

# %% [markdown]
# # Retrieval

# %%
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 4})

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'GoogleGenerativeAIEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x7f5afd651040>, search_kwargs={'k': 4})

# %%
retriever.invoke("what is protein folding")
# Out:
# [Document(id='44898221-42a6-4437-9be5-f08e2d204cd1', metadata={}, page_content="familiar, this is part of the mTOR signaling pathway. So one of the--\ntwo of the targets of mTOR, when it's stimulated--\nand leucine stimulates mTOR. Two of the targets of mTOR are a\nprotein compound called 4E-BP1. And then another one is called\na ribosomal protein S6K. So I don't want to get\ninto the specifics about it because it's going\nto be on the scope. But basically, when these things\nare phosphorylated by mTOR, it increases the rate of\ntranslation initiation, which translation initiation\nis, basically, the process of the ribosome\nhooking on to the mRNA and then starting\nprotein synthesis. So I was looking at\nthe phosphorylation of 4E-BP1 and RPS6. I was like, OK,\nwell, I'll probably see these things come\ndown in three hours. Still plateaued. And so then it was like,\nwhat's going on here? So I actually kept rerunning\nthe data and rerunning the data and rerunning the data. And I'll never forget, I\nwent into Lehman's office. And this is like six"),
#  Document(id='3334559d-5bbc-4d65-827a-c221700bb30b', metadata={}, page_content="is simply creating ATP, which the end\nof the line of that-- I'm going to work\nbackwards-- is what's called oxidative respiration. So that happens in\nthe mitochondria. Everybody's heard mitochondria,\na powerhouse of the cell. And that is done through\nessentially creating a hydrogen ion gradient across\nthe mitochondria, which powers the production\nof ATP by converting free phosphate plus ATP to ADP. Now the way that hydrogen\nion gradient is created is through creating hydrogen\nions that can be donated through the Krebs cycle. Now the Krebs cycle is\nlinked to glycolysis. So if we talk about\ncarbohydrate metabolism, carbohydrates basically,\nother than fructose, get converted into glucose,\nwhich can go into glycolysis, and you can produce some\nATPs through glycolysis. And then it boils\ndown to pyruvate, then acetyl-CoA, which\ngoes to the Krebs cycle, produces a lot more\nATPs from that. If you talk about\nprotein, protein is a little bit different"),
#  Document(id='45c2d40f-5cb2-4227-9799-f7d602000b66', metadata={}, page_content='protein-containing foods, they tend to become more\ndigestible, not less. Eggs are this way. Meats are this way. People say, well, when you\nheat protein, you denature it. And I think they hear\nthat word "denature," and they think destroy. And that is not\nwhat denature means. So proteins fold up into\n3D dimensional structures, you know this of course, based\non their amino acid sequence. And there are specific\nenergies of those amino acids. When you heat\nprotein or add acid, it starts to unfold\nthat protein structure. That happens during\ndigestion anyway. So I always chuckle when-- I\'ve seen some\ncompanies come out with "way that\nyou can cook with" that\'s not going to\ndestroy the amino acids. And I\'m like, so you\nmean regular way, right? So yeah, typically,\ncooking actually makes amino acids more\nbioavailable, not less. Now, I would stay away\nfrom charring your meat because there is some\nevidence that charring creates polyaromatic hydrocarbons,'),
#  Document(id='bcf4fe06-a93e-4f0f-a7ba-19257e929a81', metadata={}, page_content="doesn't really have a storage mechanism. People will say, well, lean\ntissue is a storage mechanism. That's like saying a house is\na storage facility for wood. Yeah, if the house\nis made out of wood you could get wood out of it,\nbut that's not why you build. You're building the\nhouse out of a demand. Same thing for muscle tissue. There is a free\npool of amino acids, but it's very, very small. So when you consider things\nlike fat, which, basically, has unlimited storage capacity,\ncarbohydrate, at relatively large storage\ncapacity, you can store 400 or 500 grams of carbohydrate\nbetween your liver and muscles. And then protein, which almost\nhas no storage capacity, the idea that, OK,\nyou could make up for a low protein at one\nmeal by over consuming another meal didn't\nmake sense to me. So one of the studies we did-- and again, in rats, we took-- both groups were getting whey\nprotein, so a high quality protein, they were getting\nthe exact same amount of calories, exact same amount")]

# %% [markdown]
# ---

# %% [markdown]
# # Augmentation

# %%
llm = GoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.4)

# %%
prompt1 = PromptTemplate(
    template="""You are a helpful assistant. Answer only from the provided transcript content.If the content is insufficient just say I dont know. {context}, Question={user_question}""",
    input_variables=["context", "user_question"],
)

# %%
question = (
    "is the topic of protein discussed in the question if yes then what is discussed"
)

retrieved_docs = retriever.invoke(question)

# %%
content_text = "\n\n".join(doc.page_content for doc in retrieved_docs)

# %%
final_prompt = prompt1.invoke({"context": retrieved_docs, "user_question": question})

# %% [markdown]
# ---

# %% [markdown]
# # Generation

# %%
result = llm.invoke(final_prompt)

# %%
result
# Out:
# 'Yes, the topic of protein is discussed in the transcript.\n\nHere\'s what is discussed about protein:\n\n*   **Storage Capacity:** Protein has almost no storage capacity, unlike fat (unlimited) and carbohydrates (large capacity). This leads to questioning the idea of making up for low protein at one meal by overconsuming at another.\n*   **Studies:** A study in rats involving whey protein (a high-quality protein) is mentioned, where both groups received the same amount of calories.\n*   **Plant-Based Options:** Leucine and other essential amino acids are noted as options for plant-based individuals, and it\'s stated that plant-based people can build impressive amounts of muscle.\n*   **Dietary Importance:** Protein is considered a core component of a diet and the "biggest lever" among macronutrients.\n*   **Satiety Signals:** The relationship between protein and satiety signals is brought up.\n*   **Bioavailability:** The bioavailability of animal sources of protein for muscle building and fat loss (without losing muscle) is questioned.\n*   **Muscle Building Benefits:** The benefits for muscle building are discussed, with a plateau around 1.6 grams per kilogram of body weight.\n*   **Longevity:** It\'s mentioned that protein is not necessarily a "longevity hack," but the long-term effects of macronutrients are considered.'

# %% [markdown]
# ---

# %% [markdown]
# # With Chain

# %%
prompt1 = PromptTemplate(
    template="""You are a helpful assistant. Answer only from the provided transcript content.If the content is insufficient just say I dont know. {context}, Question={user_question}""",
    input_variables=["context", "user_question"],
)

# %%
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 4})

# %%
from langchain_core.runnables import (
    RunnableParallel,
    RunnablePassthrough,
    RunnableLambda,
)
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

# %%
# parallel chains
# question | passthrough
# question | retriever
# both augment then |prompt|llm

# %%
def format_docs(retrieved_docs):
    content_text = "\n\n".join(doc.page_content for doc in retrieved_docs)
    return content_text

# %%
parallel_chain = RunnableParallel(
    {
        "context": retriever | RunnableLambda(format_docs),
        "user_question": RunnablePassthrough(),
    }
)

# %%
parallel_chain.invoke("how much protein is sufficient for body")
# Out:
# {'context': "to get a lot of the muscle building benefits. I mean, I think\nthe benefits really start to plateau out around\n1.6 grams per kilogram of body weight. There's some evidence\nthat maybe even up to like 2.4 or\n2.8 grams per kilo may give a little\nbit more benefit. I think it probably\nlooks something like an asymptote\nin terms of a curve where as you put\nmore into the system, you always get a\nlittle bit more, but it just gets to the point\nwhere it's so infinitesimally small benefit that it's for all\nintensive purposes, no benefit. ANDREW HUBERMAN: But you\nmentioned 1.6 grams of protein per kilogram of body\nweight, would you consider that a threshold\nthat most people should try and achieve daily? LAYNE NORTON: I see very few\ndownsides to hitting that. I mean, I know some\npeople-- and this is going to get into a\nseparate conversation. But I know some\npeople will say, well, I don't want to stimulate\nmTOR because that's going to make me die early. And I think, one of\n\nif you will. And how much they should focus\non protein as a core component of creating this diet. Assuming everything else\nis being done correctly. They're going to hit the\nright number of calories relative to their\noutput NEAT, et cetera. How should we think about\nprotein and satiety signals? And are animal sources\nof protein, indeed, more bioavailable? That's a tricky word. For sake of muscle\nbuilding, but also for sake of somebody who just\nwould like to lose body fat. They don't want to\nlose muscle and they'd like to bring their\nweight down a few pounds. LAYNE NORTON: So\na lot of things-- ANDREW HUBERMAN: --or more. LAYNE NORTON: Yeah. A lot of things to unpack there. Of the macronutrients,\nprotein is definitely the biggest lever that you\ncan pull, because even if-- it doesn't take a ton of protein\nto get a lot of the muscle building benefits. I mean, I think\nthe benefits really start to plateau out around\n1.6 grams per kilogram of body weight. There's some evidence\n\nthat you could answer it now. In the context of\nthis, if I'm going to eat let's say, 2 grams per\nkilogram of body weight protein and I'm not eating\nmultiple meals, maybe I'm eating two\nor three meals per day, I'm certainly going\nto be eating more than the 30-gram threshold\nthat was thrown around for a long time that\nwe can only assimilate 30 grams of protein per meal. Should I just not\nworry about that? Some of it is going to go\ntowards the thermic effect of food, some of that\nmight be converted into glucose of all things\nthrough gluconeogenesis. So should I worry about\nthis 30-gram cut off? Because I think balancing the\n1.6 gram per kilogram body weight threshold\nwith number of meals, with the need to exercise\nand work and live my life and sleep, et\ncetera, pretty soon, you run into bottlenecks\nwhere you just can't do it or you're spending so much\ntime trying to focus on it. LAYNE NORTON: You can't\noptimize all the things at the same time. ANDREW HUBERMAN: You'd lose\n\n4 grams per kilogram of protein, they couldn't really find\nany negative health outcomes from it other than people were\njust so satiated, they ended up eating less calories. So protein is a big\nlever, because one, it has a higher thermic\neffect of food, so you're getting a little\nbit more calorie burn per day even though it's not\na ton because TEF is a pretty small percentage\nof your overall energy expenditure. But still a benefit. You're getting the\neffects on lean body mass. If you're in a diet, it's going\nto help preserve lean body mass, if you're at\nmaintenance, it's going to help build a\npreserved lean body mass, and if you're in a\nsurplus, it's going to help build a\npreserved lean body mass. Then you get the\neffects on appetite. So now, I want to be careful\nbecause appetite effects tend to be very specific\nto individual foods. So you can take a\nhigh protein food and make it not very satiating. So take, for example, like\na really tasty protein bar,  ...
#  'user_question': 'how much protein is sufficient for body'}

# %%
chain1 = parallel_chain | prompt1 | llm | parser

# %%
chain1.invoke("how much protein should a person eat normally")
# Out:
# "The benefits of muscle building start to plateau around 1.6 grams per kilogram of body weight. There is some evidence that up to 2.4 or 2.8 grams per kilo may give a little more benefit, but it's an infinitesimally small benefit. Layne Norton sees very few downsides to hitting 1.6 grams of protein per kilogram of body weight daily."

# %%
chain1.invoke("who is sundar pichhai")
# Out:
# "I don't know."

# %%
chain1.invoke("what is google")
# Out:
# "I don't know."

# %%
parallel_chain.invoke("how much protein should a person eat normally")
# Out:
# {'context': "to get a lot of the muscle building benefits. I mean, I think\nthe benefits really start to plateau out around\n1.6 grams per kilogram of body weight. There's some evidence\nthat maybe even up to like 2.4 or\n2.8 grams per kilo may give a little\nbit more benefit. I think it probably\nlooks something like an asymptote\nin terms of a curve where as you put\nmore into the system, you always get a\nlittle bit more, but it just gets to the point\nwhere it's so infinitesimally small benefit that it's for all\nintensive purposes, no benefit. ANDREW HUBERMAN: But you\nmentioned 1.6 grams of protein per kilogram of body\nweight, would you consider that a threshold\nthat most people should try and achieve daily? LAYNE NORTON: I see very few\ndownsides to hitting that. I mean, I know some\npeople-- and this is going to get into a\nseparate conversation. But I know some\npeople will say, well, I don't want to stimulate\nmTOR because that's going to make me die early. And I think, one of\n\nthat you could answer it now. In the context of\nthis, if I'm going to eat let's say, 2 grams per\nkilogram of body weight protein and I'm not eating\nmultiple meals, maybe I'm eating two\nor three meals per day, I'm certainly going\nto be eating more than the 30-gram threshold\nthat was thrown around for a long time that\nwe can only assimilate 30 grams of protein per meal. Should I just not\nworry about that? Some of it is going to go\ntowards the thermic effect of food, some of that\nmight be converted into glucose of all things\nthrough gluconeogenesis. So should I worry about\nthis 30-gram cut off? Because I think balancing the\n1.6 gram per kilogram body weight threshold\nwith number of meals, with the need to exercise\nand work and live my life and sleep, et\ncetera, pretty soon, you run into bottlenecks\nwhere you just can't do it or you're spending so much\ntime trying to focus on it. LAYNE NORTON: You can't\noptimize all the things at the same time. ANDREW HUBERMAN: You'd lose\n\nif you will. And how much they should focus\non protein as a core component of creating this diet. Assuming everything else\nis being done correctly. They're going to hit the\nright number of calories relative to their\noutput NEAT, et cetera. How should we think about\nprotein and satiety signals? And are animal sources\nof protein, indeed, more bioavailable? That's a tricky word. For sake of muscle\nbuilding, but also for sake of somebody who just\nwould like to lose body fat. They don't want to\nlose muscle and they'd like to bring their\nweight down a few pounds. LAYNE NORTON: So\na lot of things-- ANDREW HUBERMAN: --or more. LAYNE NORTON: Yeah. A lot of things to unpack there. Of the macronutrients,\nprotein is definitely the biggest lever that you\ncan pull, because even if-- it doesn't take a ton of protein\nto get a lot of the muscle building benefits. I mean, I think\nthe benefits really start to plateau out around\n1.6 grams per kilogram of body weight. There's some evidence\n\nwhere you just can't do it or you're spending so much\ntime trying to focus on it. LAYNE NORTON: You can't\noptimize all the things at the same time. ANDREW HUBERMAN: You'd lose\nyour mind and your body. So what is necessary\nin terms of frequency if one is getting\nenough protein? And then tied into\nthat question, is there any\nreality to this idea that if you eat one meal\nper day or you're fasting and then you eat, let's\nsay, 200 grams of protein in a single feeding, that you\ncan assimilate more because you were protein starved. Is that a real thing? LAYNE NORTON: So most of\nthe studies with protein are after a fast because to\nassess it with stable isotope, you have to be in\na steady state. So we haven't observed that. It doesn't appear\nthat fasting really allows you to assimilate\nmore protein after a fast. So this gets into a core\nof one of the things I looked at in my\nPhD, which is, does protein distribution matter? Because most Americans get about",
#  'user_question': 'how much protein should a person eat normally'}

# %%
chain1.invoke("how much protein should a person eat normally")
# Out:
# 'A person should aim for around 1.6 grams of protein per kilogram of body weight daily. The benefits for muscle building start to plateau at this amount. There\'s some evidence that up to 2.4 or 2.8 grams per kilo may offer a "little bit more benefit," but this benefit is described as "infinitesimally small." Layne Norton sees "very few downsides" to hitting the 1.6 grams per kilogram threshold daily.'
